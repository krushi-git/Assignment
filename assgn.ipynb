# %%
#types of applications in python
    """ 1.Web Applications
        2.Desktop Applications
        3.Data Science and Data Analysis Applications
        4.Machine Learning and AI Applications
        5.Automation Scripts
        6.Game Development
        7.Networking Applications
        8.Scientific and Mathematical Applications
     """

# %%
#What is programming
""" Programming means writing instructions for a computer so it can perform a specific task.
    Programming is telling the computer what to do step by step.
"""

# %%
# What is Python?
"""Python is a high-level, interpreted, general-purpose programming language designed to be simple, readable, and easy to learn. It is used to develop many types of applications such as web applications, data analysis programs, automation scripts, artificial intelligence systems, and desktop software. 
"""

# %%
# Write a Python program to check if a number is positive, negative or zero. 
a=int(input("Enter a number: "))

if a>0:
    print("Number is positive")
elif a<0:
    print("Number is negative")
else:
    print("Number is zero")
# Out:
# Enter a number:  5
# Number is positive

# %%
# Write a Python program to get the Factorial number of given numbers.
n = int(input("Enter a number: "))
fact = 1
for i in range(1,n+1):
    fact *=i
print(fact)
# Out:
# Enter a number:  5
# 120

# %%
# Write a Python program to get the Fibonacci series of given range. 
n = int(input("Enter number: "))
a, b = 0, 1
for i in range(n):
    print(a, end=" ")
    a, b = b, a + b
# Out:
# Enter number:  7
# 0 1 1 2 3 5 8

# %%
# How memory is managed in Python?
""" Memory management in Python means how Python stores, uses, and frees memory while a program is running.
Python manages memory automatically, so the programmer usually does not need to handle it manually.
"""

# %%
# What is the purpose continuing statement in python?
""" The continue statement is used inside loops to skip the current iteration and move to the next iteration of the loop."""

# %%
# Write python program that swap two number with temp variable and without temp variable.
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

a, b = b, a

print("After swapping:")
print("a =", a)
print("b =", b)
# Out:
# Enter first number:  6
# Enter second number:  8
# After swapping:
# a = 8
# b = 6

# %%
# Write a Python program to find whether a given number is even or odd, print out an appropriate message to the user.
a=int(input("Enter a number: "))

if a%2==0:
    print("Number is even")
else:
    print("Number is odd")
# Out:
# Enter a number:  6
# Number is even

# %%
# Write a Python program to test whether a passed letter is a vowel or not. 
a=input("Enter a letter: ")

if a in "aeiouAEIOU":
    print("Letter is vowel")
else:
    print("Letter is not vowel")
# Out:
# Enter a letter:  A
# Letter is vowel

# %%
# Write a Python program to sum of three given integers. However, if two values are equal sum will be zero. 
a=int(input("Enter first number: "))
b=int(input("Enter second number: "))
c=int(input("Enter third number: "))

if a==b or b==c or c==a:
    print("Sum: 0")
else:
    print("Sum: ",a+b+c)
# Out:
# Enter first number:  8
# Enter second number:  8
# Enter third number:  4
# Sum: 0

# %%
# Write a Python program that will return true if the two given integer values are equal or their sum or difference is 5. 
a=int(input("Enter first number: "))
b=int(input("Enter second number: "))

if a==b or a+b==5 or a-b==5:
    print("True")
else:
    print("False")
# Out:
# Enter first number:  8
# Enter second number:  3
# True

# %%
# Write a python program to sum of the first n positive integers. 
a = int(input("Enter a positive integer: "))

sum = 0
for i in range(1, a + 1):
    sum += i

print("The sum of first", a, "positive integers is:", sum)
# Out:
# Enter a positive integer:  10
# The sum of first 10 positive integers is: 55

# %%
# Write a Python program to calculate the length of a string. 
text = input("Enter a string: ")
length = len(text)
print("The length of the string is:", length)
# Out:
# Enter a string:  Hello World
# The length of the string is: 11

# %%
#  Write a Python program to count the number of characters (character frequency) in a string 
text = input("Enter a string: ")
freq = {}

for char in text:
    if char in freq:
        freq[char] += 1
    else:
        freq[char] = 1

print("Character Frequency:")
for char, count in freq.items():
    print(char, ":", count)
# Out:
# Enter a string:  Heyy! Krushi here.
# Character Frequency:
# H : 1
# e : 3
# y : 2
# ! : 1
#   : 2
# K : 1
# r : 2
# u : 1
# s : 1
# h : 2
# i : 1
# . : 1

# %%
#  What are negative indexes and why are they used?
"""Negative indexes in Python are a way to access elements from the end of a list, string, or any sequence.
They are used to easily access elements from the end, avoid errors when length changes and useful in slicing"""

# %%
# Write a Python program to count occurrences of a substring in a string.
text = input("Enter the main string: ")
sub = input("Enter the substring to search: ")

count = 0
index = 0

while index < len(text):
    index = text.find(sub, index)
    if index == -1:
        break
    count += 1
    index += len(sub)

print("Number of occurrences:", count)
# Out:
# Enter the main string:  My name is Krushi
# Enter the substring to search:  My full name is Krushi Mehta
# Number of occurrences: 0

# %%
# Write a Python program to count the occurrences of each word in a given sentence.
sentence = input("Enter a sentence: ")

words = sentence.split()
freq = {}

for word in words:
    word = word.lower()
    if word in freq:
        freq[word] += 1
    else:
        freq[word] = 1

print("Word Frequency:")
for word, count in freq.items():
    print(word, ":", count)
# Out:
# Enter a sentence:  I am very happy and had a very good happy day.
# Word Frequency:
# i : 1
# am : 1
# very : 2
# happy : 2
# and : 1
# had : 1
# a : 1
# good : 1
# day. : 1

# %%
# Write a Python program to get a single string from two given strings,separated by a space and swap the first two characters of each string.
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")

# Swap first two characters
new_str1 = str2[:2] + str1[2:]
new_str2 = str1[:2] + str2[2:]

# Join with a space
result = new_str1 + " " + new_str2

print("Result:", result)
# Out:
# Enter first string:  what is your name
# Enter second string:  my name is Krushi
# Result: myat is your name wh name is Krushi

# %%
# Write a Python program to add 'in' at the end of a given string (length should be at least 3). If the given string already ends with 'ing' then add 'ly' instead if the string length of the given string is less than 3,leave it unchanged.
text = input("Enter a string: ")

if len(text) < 3:
    result = text
elif text.endswith("ing"):
    result = text + "ly"
else:
    result = text + "ing"

print("Result:", result)
# Out:
# Enter a string:  today is thrusday
# Result: today is thrusdaying

# %%
# Write a Python function to reverses a string if its length is a multiple of 4.
def reverse_if_multiple_of_4(text):
    if len(text) % 4 == 0:
        return text[::-1]   
    else:
        return text

# Example usage
s = input("Enter a string: ")
print("Result:", reverse_if_multiple_of_4(s))
# Out:
# Enter a string:  hey, how are you
# Result: uoy era woh ,yeh

# %%
# Write a Python program to get a string made of the first 2 and the last 2 chars from a given a string. If the string length is less than 2, return instead of the empty string.
text = input("Enter a string: ")

if len(text) < 2:
    result = ""
else:
    result = text[:2] + text[-2:]

print("Result:", result)
# Out:
# Enter a string:  hello, what are you doing
# Result: heng

# %%
# Write a Python function to insert a string in the middle of a string
def insert_in_middle(main_str, insert_str):
    middle = len(main_str) // 2
    return main_str[:middle] + insert_str + main_str[middle:]

# Example usage
s1 = input("Enter the main string: ")
s2 = input("Enter the string to insert: ")

result = insert_in_middle(s1, s2)
print("Result:", result)
# Out:
# Enter the main string:  my name krushi
# Enter the string to insert:   is
# Result: my name is krushi

# %%
# What is List? How will you reverse a list?
"""A list in Python is an ordered, mutable (changeable) collection of items.
It can store different data types such as integers, strings, floats, or even other lists.
you can reverse a string 1-Using reverse(),

my_list = [1, 2, 3, 4, 5]
my_list.reverse()
print(my_list)
"""

# %%
# How will you remove last object from a list?
#first
my_list = [100, 200, 300, 400]
my_list.pop()
print(my_list)
# Out:
# [100, 200, 300]

# %%
#  Suppose list1 is [2, 33, 222, 14, and 25], what is list1 [1]?
"""In Python, list indexing starts from 0.
so if yo are asking for list[1] means asking for the element which are at index no 2
so i will be 33"""

# %%
#  Differentiate between append () and extend () methods?
"""Append() adds a single element to the end of the list.
whereas Extend() adds a single element to the end of the list."""

# %%
# Write a Python function to get the largest number, smallest num and sum of all from a list
def list_stats(numbers):
    largest = max(numbers)
    smallest = min(numbers)
    # Use the built-in sum explicitly to avoid conflicts
    total_sum = __builtins__.sum(numbers)
    return largest, smallest, total_sum


nums = [11, 10, 6, 7, 25]
largest, smallest, total = list_stats(nums)

print("Largest number:", largest)
print("Smallest number:", smallest)
print("Sum of all numbers:", total)
# Out:
# Largest number: 25
# Smallest number: 6
# Sum of all numbers: 59

# %%
#  How will you compare two lists?
"""" we can check with these methods

a-  == → Check if both lists are exactly equal (same elements, same order).
b- sorted() → Sort both lists and compare to ignore order.
c- Counter() → Compare element frequencies, works with duplicates regardless of order.
d- zip() → Compare elements one by one to find position-wise differences.
e- len() → Compare lengths of the lists."""

# %%
# Write a Python program to count the number of strings where the string length is 2 or more and the first and last character are same from a given list of strings. 
def count_special_strings(strings):
    count = 0
    for s in strings:
        if len(s) >= 2 and s[0] == s[-1]:
            count += 1
    return count

# Example usage
words = ['pqr', 'aa', 'def', '6204', 'a', '8124']
result = count_special_strings(words)
print("Number of special strings:", result)
# Out:
# Number of special strings: 1

# %%
# Write a Python program to remove duplicates from a list.
my_list = [2, 2, 3, 5, 4, 1, 1]
unique_list = []

for item in my_list:
    if item not in unique_list:
        unique_list.append(item)

print("List after removing duplicates:", unique_list)
# Out:
# List after removing duplicates: [2, 3, 5, 4, 1]

# %%
#  Write a Python program to check a list is empty or not.
my_list = []

if not my_list:
    print("The list is empty.")
else:
    print("The list is not empty.")
# Out:
# The list is empty.

# %%
# Write a Python function that takes two lists and returns true if they have at least one common member.
def common_member(list1, list2):
    for item in list1:
        if item in list2:
            return True
    return False

# Example usage
list1 = [5, 6, 3, 4]
list2 = [1, 2, 3]

if common_member(list1, list2):
    print("True")
else:
    print("False")
# Out:
# True

# %%
# Write a Python program to generate and print a list of first and last 5 elements where the values are square of numbers between 1 and 30.
squares = [x**2 for x in range(1, 31)]

result = squares[:5] + squares[-5:]

print("List of first and last 5 elements:", result)
# Out:
# List of first and last 5 elements: [1, 4, 9, 16, 25, 676, 729, 784, 841, 900]

# %%
#  Write a Python function that takes a list and returns a new list with unique elements of the first list.
def unique_list(lst):
    unique = []
    for item in lst:
        if item not in unique:
            unique.append(item)
    return unique

# Example usage
my_list = [1, 2, 3, 3, 4, 5, 5]
print("Unique elements:", unique_list(my_list))
# Out:
# Unique elements: [1, 2, 3, 4, 5]

# %%
# Write a Python program to convert a list of characters into a string.
char_list = ['H', 'e', 'l', 'l', 'o']

# Convert list to string
result = ''.join(char_list)

print("The join string is:", result)
# Out:
# The join string is: Hello

# %%
# Write a Python program to select an item randomly from a list.
import random

my_list = [10, 20, 30, 40, 50,60,70,80]
item = random.choice(my_list)
print("Randomly selected item:", item)
# Out:
# Randomly selected item: 30

# %%
#  Write a Python program to find the second smallest number in a list.
numbers = [50, 71, 69, 22, 76]

# Method: sort and get second element
numbers_sorted = sorted(numbers)
second_smallest = numbers_sorted[1]

print("Second smallest number is:", second_smallest)
# Out:
# Second smallest number is: 50

# %%
# Write a Python program to get unique values from a list
my_list = [1, 2, 3, 3, 4, 4, 5]

# Using set
unique_values = list(set(my_list))
print("Unique values:", unique_values)
# Out:
# Unique values: [1, 2, 3, 4, 5]

# %%
# Write a Python program to check whether a list contains a sub list
def contains_sublist(lst, sublst):
    for i in range(len(lst) - len(sublst) + 1):
        if lst[i:i+len(sublst)] == sublst:
            return True
    return False

my_list = [1, 2, 3, 4, 5]
sub_list = [2, 3]
print("Contains sublist?", contains_sublist(my_list, sub_list))
# Out:
# Contains sublist? True

# %%
# Write a Python program to split a list into different variables.
my_list = [1, 2, 3]

a, b, c = my_list
print(a, b, c)
# Out:
# 1 2 3

# %%
# What is tuple? Difference between list and tuple.
"""Tuple is an ordered, immutable collection in Python.it can store different data types.
Where as list mutable collection in python.it is slower than tuple and list has more methods than tuple because list is mutable
"""

# %%
# Write a Python program to create a tuple with different data types.
my_tuple = (10, "pandas", 6.8, True)
print(my_tuple)
# Out:
# (10, 'pandas', 6.8, True)

# %%
# Write a Python program to unzip a list of tuples into individual lists.
list_of_tuples = [(1, 'a'), (2, 'b'), (3, 'c')]

numbers, letters = zip(*list_of_tuples)

print("Numbers:", list(numbers))
print("Letters:", list(letters))
# Out:
# Numbers: [1, 2, 3]
# Letters: ['a', 'b', 'c']

# %%
# Write a Python program to convert a list of tuples into a dictionary.
list_of_tuples = [('a', 1), ('b', 2), ('c', 3)]
my_dict = dict(list_of_tuples)
print(my_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
#  How will you create a dictionary using tuples in python?
tuples = [('name', 'Krushi'), ('age', 22), ('city', 'SUrat')]

my_dict = dict(tuples)
print(my_dict)
# Out:
# {'name': 'Krushi', 'age': 22, 'city': 'SUrat'}

# %%
# Write a Python script to sort (ascending and descending) a dictionary by value.
my_dict = {'pineapple': 10, 'kiwi': 5, 'mango': 15}

# Ascending
asc_sorted = dict(sorted(my_dict.items(), key=lambda x: x[1]))
print("Ascending:", asc_sorted)

# Descending
desc_sorted = dict(sorted(my_dict.items(), key=lambda x: x[1], reverse=True))
print("Descending:", desc_sorted)
# Out:
# Ascending: {'kiwi': 5, 'pineapple': 10, 'mango': 15}
# Descending: {'mango': 15, 'pineapple': 10, 'kiwi': 5}

# %%
# Write a Python script to concatenate following dictionaries to create a new one.
dict1 = {'a': 1, 'b': 2}
dict2 = {'c': 3, 'd': 4}
dict3 = {'e': 5}

new_dict = {**dict1, **dict2, **dict3}
print(new_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}

# %%
# Write a Python script to check if a given key already exists in a dictionary.
my_dict = {'a': 1, 'b': 2, 'c': 3}
key_to_check = 'b'

if key_to_check in my_dict:
    print(f"Key '{key_to_check}' exists in the dictionary")
else:
    print(f"Key '{key_to_check}' does not exist")
# Out:
# Key 'b' exists in the dictionary

# %%
# How Do You Traverse Through a Dictionary Object in Python?
my_dict = {'a': 1, 'b': 2, 'c': 3}

# 1. Traverse keys
for key in my_dict:
    print(key, my_dict[key])

# 2. Traverse keys using .keys()
for key in my_dict.keys():
    print(key, my_dict[key])

# 3. Traverse values
for value in my_dict.values():
    print(value)

# 4. Traverse key-value pairs using .items()
for key, value in my_dict.items():
    print(key, value)
# Out:
# a 1
# b 2
# c 3
# a 1
# b 2
# c 3
# 1
# 2
# 3
# a 1
# b 2
# c 3

# %%
#  How Do You Check the Presence of a Key in A Dictionary?
my_dict = {'a': 1, 'b': 2, 'c': 3}
key_to_check = 'b'

if key_to_check in my_dict:
    print(f"Key '{key_to_check}' exists in the dictionary")
else:
    print(f"Key '{key_to_check}' does not exist")
# Out:
# Key 'b' exists in the dictionary

# %%
#  Write a Python script to print a dictionary where the keys are numbers between 1 and 15.
my_dict = {x: x**2 for x in range(1, 16)}  
print(my_dict)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225}

# %%
# Write a Python program to check multiple keys exists in a dictionary
my_dict = {'a': 1, 'b': 2, 'c': 3}
keys_to_check = ['a', 'b']

if all(key in my_dict for key in keys_to_check):
    print("All keys exist")
else:
    print("Not all keys exist")
# Out:
# All keys exist

# %%
#  Write a Python script to merge two Python dictionaries
dict1 = {'a': 1, 'b': 2}
dict2 = {'c': 3, 'd': 4}

# Method 1: Using unpacking
merged_dict = {**dict1, **dict2}

# Method 2: Using update
dict1.update(dict2)

print("Merged dictionary:", merged_dict)
# Out:
# Merged dictionary: {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
# Write a Python program to map two lists into a dictionary Sample output: Counter ({'a': 400, 'b': 400,’d’: 400, 'c': 300}).
from collections import Counter

keys = ['a', 'b', 'd', 'c']
values = [500, 400, 500, 200]

result = dict(zip(keys, values))
print("Mapped dictionary:", Counter(result))
# Out:
# Mapped dictionary: Counter({'a': 500, 'd': 500, 'b': 400, 'c': 200})

# %%
# Write a Python program to find the highest 3 values in a dictionary
my_dict = {'a': 400, 'b': 100, 'c': 300, 'd': 200}

# Using sorted
top3 = sorted(my_dict.values(), reverse=True)[:3]
print("Top 3 values:", top3)
# Out:
# Top 3 values: [400, 300, 200]

# %%
'''58) Write a Python program to combine values in python list of dictionaries.
Sample data: [{'item': 'item1', 'amount': 400}, {'item': 'item2', 'amount': 300}, o {'item': 'item1', 'amount': 750}]
Expected Output: Counter ({'item1': 1150, 'item2': 300}) '''
from collections import Counter

data = [
    {'item': 'item1', 'amount': 500},
    {'item': 'item2', 'amount': 650},
    {'item': 'item1', 'amount': 250}
]

result = Counter()
for d in data:
    result[d['item']] += d['amount']

print(result)
# Out:
# Counter({'item1': 750, 'item2': 650})

# %%
# Write a Python program to create a dictionary from a string. Note: Track the count of the letters from the string.
from collections import Counter

# Input string
s = input("Enter a string: ")

# Count each character
letter_count = Counter(s)

print("Dictionary with letter counts:", dict(letter_count))
# Out:
# Enter a string:  hello, how are you all?
# Dictionary with letter counts: {'h': 2, 'e': 2, 'l': 4, 'o': 3, ',': 1, ' ': 4, 'w': 1, 'a': 2, 'r': 1, 'y': 1, 'u': 1, '?': 1}

# %%
#  Sample string:
'''w3resource' Expected output:
• {'3': 1,’s’: 1, 'r': 2, 'u': 1, 'w': 1, 'c': 1, 'e': 2, 'o': 1}'''
s = 'w3resource'
letter_count = {}

for char in s:
    if char in letter_count:
        letter_count[char] += 1
    else:
        letter_count[char] = 1

print(letter_count)
# Out:
# {'w': 1, '3': 1, 'r': 2, 'e': 2, 's': 1, 'o': 1, 'u': 1, 'c': 1}

# %%
# Write a Python function to calculate the factorial of a number (a nonnegative integer)
def factorial(n):
    if n < 0:
        return "Factorial not defined for negative numbers"
    result = 1
    for i in range(1, n+1):
        result *= i
    return result


print(factorial(6))
# Out:
# 720

# %%
# Write a Python function to check whether a number is in a given range
def is_in_range(num, start, end):
    return start <= num <= end

print(is_in_range(5, 1, 10)) 
print(is_in_range(12, 1, 10))
# Out:
# True
# False

# %%
#  Write a Python function to check whether a number is perfect or not.
def is_perfect(n):
    """
    Check whether a number is perfect.
    A perfect number is equal to the sum of its proper divisors.
    """
    if n < 1:
        return False
    divisors_sum = __builtins__.sum(i for i in range(1, n) if n % i == 0)

    return divisors_sum == n

print(is_perfect(6))   
print(is_perfect(28))  
print(is_perfect(12))  
print(is_perfect(1))
# Out:
# True
# True
# False
# False

# %%
#  Write a Python function that checks whether a passed string is palindrome or not.
def is_palindrome(s):
    return s == s[::-1]

print(is_palindrome("radar"))  
print(is_palindrome("hello"))
# Out:
# True
# False

# %%
# How Many Basic Types of Functions Are Available in Python?
'''Python has four basic types of functions:

1- User-defined functions – defined by the user using def
2- Built-in functions – like print(), len(), sum()
3- Anonymous (lambda) functions – short, inline functions using lambda
4- Recursive functions – functions that call themselves'''

# %%
# How can you pick a random item from a list or tuple?
import random

my_list = [1, 2, 3, 4, 5]
print(random.choice(my_list))
# Out:
# 5

# %%
#How can you pick a random item from a range?
import random

print(random.choice(range(1, 11)))
# Out:
# 2

# %%
# How can you get a random number in python?
import random

print(random.random())  
print(random.randint(1, 100))
# Out:
# 0.413943203419574
# 79

# %%
# How will you set the starting value in generating random numbers?
import random

random.seed(10)   # Set the seed
print(random.randint(1, 100))
print(random.randint(1, 100))
# Out:
# 74
# 5

# %%
#  How will you randomize the items of a list in place?
import random

my_list = [1, 2, 3, 4, 5]
random.shuffle(my_list)  
print(my_list)
# Out:
# [1, 3, 5, 4, 2]

# %%
# What is File function in python? What are keywords to create and write file
'''In Python, files are handled using the open() function.
Common modes:

'r' → read
'w' → write (creates file if it doesn’t exist)
'a' → append
'rb' / 'wb' → read/write in binary mode'''
f = open('example.txt', 'w')  
f.write("Hello, World!")
f.close()

# %%
#  Write a Python program to read an entire text file.
with open('example.txt', 'r') as f:
    content = f.read()
print(content)
# Out:
# Hello, World!

# %%
# Write a Python program to append text to a file and display the text.
with open('example.txt', 'a') as f:
    f.write("\nThis is appended text.")

with open('example.txt', 'r') as f:
    print(f.read())
# Out:
# Hello, World!
# This is appended text.

# %%
# Write a Python program to read first n lines of a file.
n = 3
with open('example.txt', 'r') as f:
    for i in range(n):
        print(f.readline(), end='')
# Out:
# Hello, World!
# This is appended text.

# %%
# Write a Python program to read last n lines of a file.
n = 3
with open('example.txt', 'r') as f:
    lines = f.readlines()
    print(''.join(lines[-n:]))
# Out:
# Hello, World!
# This is appended text.

# %%
# Write a Python program to read a file line by line and store it into a list
with open('example.txt', 'r') as f:
    lines_list = f.readlines()

print(lines_list)
# Out:
# ['Hello, World!\n', 'This is appended text.']

# %%
#  Write a Python program to read a file line by line store it into a variable.
with open('example.txt', 'r') as f:
    content = f.read()

print(content)
# Out:
# Hello, World!
# This is appended text.

# %%
#  Write a python program to find the longest words.
with open('example.txt', 'r') as f:
    words = f.read().split()

max_len = max(len(word) for word in words)
longest_words = [word for word in words if len(word) == max_len]
print("Longest words:", longest_words)
# Out:
# Longest words: ['appended']

# %%
# Write a Python program to count the number of lines in a text file.

with open('example.txt', 'r') as f:
    line_count = __builtins__.sum(1 for _ in f)

print("Number of lines:", line_count)
# Out:
# Number of lines: 2

# %%
#  Write a Python program to count the frequency of words in a file.
from collections import Counter

with open('example.txt', 'r') as f:
    words = f.read().split()

word_freq = Counter(words)
print(word_freq)
# Out:
# Counter({'Hello,': 1, 'World!': 1, 'This': 1, 'is': 1, 'appended': 1, 'text.': 1})

# %%
#  Write a Python program to write a list to a file.
my_list = ['apple', 'banana', 'cherry']
with open('output.txt', 'w') as f:
    for item in my_list:
        f.write(item + '\n')

# %%
# Write a Python program to copy the contents of a file to another file.
with open('example.txt', 'r') as source:
    with open('copy.txt', 'w') as dest:
        dest.write(source.read())

# %%
# Explain Exception handling? What is an Error in Python?
'''Exception handling: Manage runtime errors using try-except blocks.
Error: A problem in code execution. Can be syntax error or runtime error.'''
try:
    x = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# Cannot divide by zero

# %%
# How many except statements can a try-except block have? Name Some built-in exception classes:
'''A try block can have multiple except blocks.

Some built-in exceptions:

ZeroDivisionError, ValueError, TypeError, IndexError, KeyError, FileNotFoundError, ImportError'''

# %%
# When will the else part of try-except-else be executed?
'''The else part of try-except-else is executed only if no exception occurs in the try block.'''
try:
    x = 10 / 2
except ZeroDivisionError:
    print("Error occurred")
else:
    print("No error, division successful")
# Out:
# No error, division successful

# %%
#  Can one block of except statements handle multiple exception?
'''Yes, using a tuple of exceptions'''
try:
    x = int("abc")
except (ValueError, TypeError) as e:
    print("Error:", e)
# Out:
# Error: invalid literal for int() with base 10: 'abc'

# %%
# When is the finally block executed?
'''The finally block is always executed, regardless of whether an exception occurred or not.
It is often used to release resources, like closing files or network connections.'''

try:
    x = 10 / 0
except ZeroDivisionError:
    print("Error occurred")
finally:
    print("This will always execute")
# Out:
# Error occurred
# This will always execute

# %%
#  What happens when „1‟== 1 is executed?
""" '1' is a string, 1 is an integer.Python does not automatically convert types in comparisons.
so result will be False"""
print('1' == 1)
# Out:
# False

# %%
# How Do You Handle Exceptions with Try/Except/Finally in Python? Explain with coding snippets.
try:
    x = int(input("Enter a number: "))
    result = 10 / x
except ValueError:
    print("Invalid input. Please enter a number.")
except ZeroDivisionError:
    print("Cannot divide by zero.")
finally:
    print("This will always execute.")

'''try → code that may raise exceptions
except → handle specific exceptions
finally → executes no matter what'''
# Out:
# Enter a number:  5
# This will always execute.
# 'try → code that may raise exceptions\nexcept → handle specific exceptions\nfinally → executes no matter what'

# %%
# Write python program that user to enter only odd numbers, else will raise an exception.
def enter_odd_number():
    try:
        num = int(input("Enter an odd number: "))
        if num % 2 == 0:
            raise ValueError("Even number entered! Only odd numbers allowed.")
        print("You entered:", num)
    except ValueError as e:
        print("Error:", e)

enter_odd_number()
# Out:
# Enter an odd number:  4
# Error: Even number entered! Only odd numbers allowed.
